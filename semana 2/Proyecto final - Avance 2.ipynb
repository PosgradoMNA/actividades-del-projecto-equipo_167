# %% [markdown]
# <a href="https://colab.research.google.com/github/PosgradoMNA/actividades-del-projecto-equipo_167/blob/main/Proyecto%20final%20-%20Avance%202.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **Identificar una metodología que vas a usar durante la realización del proyecto.**
#
# La metodología que vamos a emplear es CRISP-DM.

# %% [markdown]
# ### **Escribe los pasos estándares en un máximo de 3 oraciones, por cada fase.**
#
# **Fase I. Entendimiento del negocio**
#
# Es la fase inicial que se enfoca en la comprensión de los objetivos del negocio en donde se toman decisiones y planteamos que objetivos queremos buscar en el proyecto con el análisis de los datos.
#
# **Fase II. Entendimiento de los datos**
#
# Consiste en el entendimiento o familiarización de los datos, es donde identificamos los problemas de calidad, descubrir conocimiento preliminar sobre los datos para empezar a formular hipótesis.
#
# **Fase III. Preparación**
#
# Abarca todas las actividades para construir el conjunto final de datos tales como: selección de tablas, registros, transformaciones y limpieza de datos para la herramienta de modelado.
#
# **Fase IV. Modelado**
#
# Se realiza la selección y se aplican las técnicas de modelados que sea adecuadas al problema, y se calibran sus parámetros a valores óptimos.
#
# **Fase V. Evaluación**
#
# Consiste en la certificación de los modelos construidos, con el fin de garantizar que cumpla con los objetivos del negocio. Al final de esta fase, se debiera obtener una decisión sobre la aplicación de los resultados del análisis de datos.
#
# **Fase VI. Despliegue**
#
# Es la puesta en producción en donde el conocimiento obtenido tendrá que organizarse y presentarse para que el cliente pueda usarlo, con el fin de garantizar el desarrollo y la transformación del negocio.

# %% [markdown]
# ### **Documentación del proceso**
#
# 1. Proceso de entendimiento del negocio vamos a realizar la siguinetes actividades:
#
#  *   Definir los objetivos y exigencia del proyecto.
#  *   Valoración de la solución de Ciencia de Datos.
#  *   Definición del problema de Ciencia de Datos.
#  *   Preparar el plan del proyecto.
#
# 2. Proceso de entendimiento de datos estaremos llevando acabo las siguientes actividades:
#
#  *   Recolección de los datos inicial.
#  *   Comprensión y análisis de la calidad de datos.
#  *   La exploración inicial de los datos.
#  *   Planteamiento de las primeras hipótesis.
#  *   Recolección de las fuentes de datos.
#
#  En esta parte de proceso existe una doble comunicación bidirecciónal con la fase del entendimiento del negocio, porque puede sugir algunas dudas por parte del equipo técnico. El objetivos es poder estar aliniado con el equipo de negocio.
#
# 3. Proceso de la preparación de datos estaremos realizando las siguientes actividades:
#
#  *   Selección de datos.
#  *   Limpieza.
#  *   Construcción de nuevas variables.
#  *   Integración de datos.
#  *   Formateo.
#
# 4. Proceso de modelado, estaremos realizando las siguientes actividades:
#
#  *   Diseño del modelo.
#  *   Entrenamiento del modelo.
#  *   Prueba del modelo.
#  *   Evaluación del rendimiento del modelo.
#
#  En esta fase del proceso existe un relación bidirecciónal entre la fase de preparación y modelado, puede exister la probalidad de que aún hay datos que no cumplan con la calidad esperada.
#
# 5. Proceso de evaluación, estaremos realizando las siguientes actividades:
#
#  *   Evaluación de los resultados.
#  *   Revisión del proceso.
#  *   Definición de la continuidad.
#
# 6. Proceso de despliegue, estaremos realizando las siguientes actividades:
#
#  *   Explotación del modelo en conjunto con el usuarios de negocio.
#
# El proceso se vuelve a repetar hasta que el modelo este los suficiente maduro y robusto.

# %% [markdown]
# ### **Diagrama del proceso**
#
# Enlace de miro: https://miro.com/welcomeonboard/Mm5UR2pMa1p4NDkyRVZoaVoxMWVEVTZoTDd6WDF1MmlYSUZqR2F0bGlXWHh3d3dWWXBFZFBsbFBVaFhOZzJCb3wzNDU4NzY0NTM0Mzg4NjA4MTU0fDI=?share_link_id=571476698448
#
# ![Untitled (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **Captura de pantalla del diagrama en miro**
#
#
# ![Captura - Diagrama CRISP - DM.PNG](data:image/png;base64,...)
